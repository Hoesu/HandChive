# %%
import matplotlib.pyplot as plt

# 주어진 데이터
data = [
    [311, 64, 640, 64, 640, 210, 311, 210],
    [1130, 68, 1377, 68, 1377, 196, 1130, 196],
    [1427, 73, 1629, 73, 1629, 183, 1427, 183],
    [709, 73, 933, 73, 933, 196, 709, 196],
    [956, 86, 1084, 86, 1084, 178, 956, 178],
    [1025, 237, 1336, 237, 1336, 370, 1025, 370],
    [526, 247, 787, 247, 787, 375, 526, 375],
    [874, 251, 1020, 251, 1020, 370, 874, 370],
    [1043, 411, 1560, 411, 1560, 553, 1043, 553],
    [1607, 404, 2168, 420, 2163, 564, 1603, 548],
    [526, 430, 626, 430, 626, 540, 526, 540],
    [654, 430, 983, 430, 983, 553, 654, 553],
    [2196, 443, 2416, 443, 2416, 567, 2196, 567],
    [640, 599, 855, 599, 855, 727, 640, 727],
    [1427, 599, 1620, 599, 1620, 736, 1427, 736],
    [878, 613, 1185, 613, 1185, 736, 878, 736],
    [1231, 613, 1405, 613, 1405, 723, 1231, 723],
    [535, 636, 599, 636, 599, 727, 535, 727],
    [1661, 778, 2306, 778, 2306, 924, 1661, 924],
    [645, 782, 874, 782, 874, 915, 645, 915],
    [942, 782, 1372, 782, 1372, 910, 942, 910],
    [1377, 791, 1615, 791, 1615, 910, 1377, 910],
    [530, 796, 645, 796, 645, 901, 530, 901]
]

# 시각화
for i, coordinates in enumerate(data):
    # 각 줄의 데이터를 4쌍의 좌표로 분할
    x = coordinates[::2]
    y = coordinates[1::2]
    
    # 처음 좌표를 리스트의 끝에 추가하여 사각형을 완성
    x += [x[0]]
    y += [y[0]]
    
    # 직사각형 그리기
    plt.plot(x, y, marker='o')
    
    # 각 사각형의 가운데 좌표 계산
    center_x = sum(x) / len(x)
    center_y = sum(y) / len(y)
    
    # 가운데에 줄의 번호 표시
    plt.text(center_x, center_y, str(i+1), color='red', ha='center', va='center')

plt.title('Rectangles Visualization with Line Numbers')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
data = [
    [311, 64, 640, 64, 640, 210, 311, 210],
    [1130, 68, 1377, 68, 1377, 196, 1130, 196],
    [1427, 73, 1629, 73, 1629, 183, 1427, 183],
    [709, 73, 933, 73, 933, 196, 709, 196],
    [956, 86, 1084, 86, 1084, 178, 956, 178],
    [1025, 237, 1336, 237, 1336, 370, 1025, 370],
    [526, 247, 787, 247, 787, 375, 526, 375],
    [874, 251, 1020, 251, 1020, 370, 874, 370],
    [1043, 411, 1560, 411, 1560, 553, 1043, 553],
    [1607, 404, 2168, 420, 2163, 564, 1603, 548],
    [526, 430, 626, 430, 626, 540, 526, 540],
    [654, 430, 983, 430, 983, 553, 654, 553],
    [2196, 443, 2416, 443, 2416, 567, 2196, 567],
    [640, 599, 855, 599, 855, 727, 640, 727],
    [1427, 599, 1620, 599, 1620, 736, 1427, 736],
    [878, 613, 1185, 613, 1185, 736, 878, 736],
    [1231, 613, 1405, 613, 1405, 723, 1231, 723],
    [535, 636, 599, 636, 599, 727, 535, 727],
    [1661, 778, 2306, 778, 2306, 924, 1661, 924],
    [645, 782, 874, 782, 874, 915, 645, 915],
    [942, 782, 1372, 782, 1372, 910, 942, 910],
    [1377, 791, 1615, 791, 1615, 910, 1377, 910],
    [530, 796, 645, 796, 645, 901, 530, 901]]

# 시각화
for i, coordinates in enumerate(data):
    # 각 줄의 데이터를 4쌍의 좌표로 분할
    x = coordinates[::2]
    y = coordinates[1::2]
    
    # 처음 좌표를 리스트의 끝에 추가하여 사각형을 완성
    x += [x[0]]
    y += [y[0]]
    
    # 직사각형 그리기
    plt.plot(x, y, marker='o')
    
    # 각 사각형의 가운데 좌표 계산
    center_x = sum(x) / len(x)
    center_y = sum(y) / len(y)
    
    # 가운데에 줄의 번호 표시
    plt.text(center_x, center_y, str(i+1), color='red', ha='center', va='center')

# y축을 반전
plt.gca().invert_yaxis()

plt.title('Rectangles Visualization with Line Numbers')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.show()
